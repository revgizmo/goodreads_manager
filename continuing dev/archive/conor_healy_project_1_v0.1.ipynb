# %% [markdown]
# # Start

# %% [markdown]
#
# # Need:
#
#
# ## Goodreads format
#
# 1. 'Title', 'Author', 'ISBN', 'My Rating', 'Average Rating', 'Publisher', 'Binding', 'Year Published', 'Original Publication Year', 'Date Read', 'Date Added', 'Bookshelves', 'My Review'
#
# ## Magic methods: sort()
# ## Interaction between objects
#
# 1. Call a method of one object to effect the state of many other objects
#      1. Books added to bookshelves
#      1. One review effects another review -
#      1. Collect a list of reviews - have a review that revises/updates other reviews.
#      1. Read next: update read next list based on type of most recent book reviewed
# 1. Menu system to help a naive user know what to do
#
# ## Bookshelf Manager Class
#
# 1. With text entry fields, let user know that escape characters (\n, etc) will be respected.
#
#
# ## Bookshelf Class
#
# 1. Create magic methods for add, sub to append, remove
# 1. InputBook(): add question: do you want to review now? and appropriate functionality
# 1. Update book_status to automatically reflect if there is a Review
# 1. Create attributes for book interactions:
#     1. Book first appeared? when read? rather than at book level
#     1. list of dates books were read/reviewed
# 1. Update Future enhancements section in Design Document
# 1. Override the append functionality: When books are appended, update the review count, status, etc.
# 1. Update \_\_init\_\_ method to prompt user for imputs for missing information
#
# ## Book Class
#
# 1. Add references to user interactions with the book instance: added to bookshelf, read, reviewed, etc..
# 1. Add ability to Edit Book instances
# 1. Return all books entered/reviewed
# 1. Return Actionable Items across all books
# 1. Override the append functionality: When reviews are appended, update the review count, status, etc.
# 1. Update sort to work with 'key = '
#
#
#
#
# ## Review Class
#
# 1. Constrain rating to 1-5
# 1. When a review is added,
#     1. Update the Bookshelf to reflect a new review
# 1. Other Notes & Takeaways: possibly class/instances?
# 1. Add ability to Edit Review
# 1. Return all reviews entered
# 1. Return Highlighted Sections across all books
# 1. Return Actionable Items across all books
#
#
#
# ## Highlighted Sections Class
#
# 1. Create class
#
# ## Actionable Items Class
#
# 1. Create class
#
# ## Format Consumed Class
#
# 1. Replace Dict with class
#
#
# ## Out of scope:
#
# 1. Reporting on number of books,
# 1. Timing of reading/reviews,
# 1. Details on highlights/quotes to separate explicit quotations from highlights/thoughts & print of explicit quotations)
# 1. Deduplication of books and reviews
#     1. Double check titles
#     1. Double check every other value at the class level
#     1. Offer to merge if missing data, and prompt user to choose between them
#     1. Prompt user throughout merge process
# 1. Edit existing books/reviews.
#     1. https://stackoverflow.com/questions/2533120/show-default-value-for-editing-on-python-input-possible/2533134
# 1. Treat review start_date and end_date as actual dates.
# 1. Add pandas visualizations for timeline of books consumed, books reviewed, etc.
# 1. Add a dash gui (Gunnar: not tkinter) or maybe pygame
# 1. Professional enhancements:
#     1. get someone to use it in the world: blog/ post code to github, get people to fork it
#     1. Web api so people can log in and manage their bookshelves.
#     1. Data science on results:
#         1. what did I read when?
#         1. What do other users do?

# %% [markdown]
# # Design Document (10 points):
#
#
# ## Summary
# 1. I intend to implement a tool to manage book ratings, reviews and thoughts.
#
# ## Expected Classes (4-5+):
#
# ### <u>__Bookshelf__</u> (class):
#
# 1. Purpose
#     1. A place for all my books
#     1. Track user interactions with books.
#     1. Future enhancement: right now, any segregation a user would want to do to separate groups of books) to manage different people, work/personal, by subject, etc.) would happen as different Bookshelf instances.  I could see possibly customizing them in the future with sub-classes.
#
# 1. Methods/functions
#     1. Managing books
#         1. __add_book__
#         1. __\_\_init\_\___
#         1. __\_\_repr\_\___
#     1. Filtering and Sorting
#         1. __Filter to top reviews__
#         1. __Subset by genre__
#         1. __Sort by various criteria__
#         1. __To read list, sorted by something__
#     1. A way to save and load my bookshelf
#         1. __save_bookshelf__
#         1. __load_bookshelf__
#     1. Ways to return/display my bookshelf
#         1. __get_books__
#         1. __print_books_titles__
#         1. __print_books_info__
#         1. __print_reviews__
#         1. __print_ascii_books__
#
# 1. Expected i/o and attributes
#     1. Class attributes
#         1. __Bookshelf.bookshelf_count__ (how many bookshelves are there?)
#         1. __Bookshelf.bookshelves__ (list of all the bookshelves)
#     1. Instance attributes
#         1. __books__ (list)
#         1. __name__
#         1. __books_count__
#         1. __reviews_count__

# %% [markdown]
# #### class Bookshelf()

# %%
import pickle


class Bookshelf():
    '''An entity that represents a place for all my books.
    
    Attributes:
    Bookshelf.bookshelf_count (how many bookshelves are there?)
    books (list)
    name
    books_count
    reviews_count
    
    Methods
    get_books
    print_books_titles
    print_books_info
    print_reviews
    print_ascii_books
    add_book
    save_bookshelf
    load_bookshelf
    '''
    bookshelf_count = 0
    bookshelves = []

    def __init__(self, name="Unnamed bookshelf"):
        self.name = name
        self.books = []
        Bookshelf.bookshelves.append(self)
        Bookshelf.bookshelf_count += 1
        self.books_count = 0
        self.reviews_count = 0

    def __str__(self):
        return self.name

    def __repr__(self):
        return self.name

    @classmethod
    def load_bookshelf(cls, file):
        return pickle.load(open(file, "rb"))

    def save_bookshelf(self):
        pickle.dump(self, open(f"{self.name}.bkshlf", "wb"))

    def get_books(self):
        return (self.books)

    def get_bookshelves():
        return (Bookshelf.bookshelves)

    def reset_bookshelf(self):
        Bookshelf.bookshelf_count = 0
        for bookshelf in Bookshelf.bookshelves:
            Bookshelf.bookshelf_count += 1

        self.books_count = 0
        self.reviews_count = 0
        for book in self.books:
            self.books_count += 1
            book.reviews_count = 0
            for review in book.reviews:
                book.reviews_count += 1
                self.reviews_count += 1

    def add_book(self, book=None):
        """Add a book to the bookshelf.  If a book is not provided, user will be prompted to add the book manually."""
        if book == None:
            book = Book()
        print(f'testing: {book}')
        self.books.append(book)
        book.bookshelves.append(self)
        self.books_count += 1

        print(f"{book.get_book_info()} \nadded to {self.name}")

    def print_bookshelf_summary(self):
        """Print the summary information for the the bookshelf."""
        
        print(f'Books: {self.books_count}\nReviews: {self.reviews_count}')


    def print_books_titles(self, sort_val=None):
        """Print the book titles for all books in the bookshelf, sorted by the sort method (if provided)."""
        if sort_val:
            raise Exception("Need to make sort() work with the Books class")
        else:
            books_sorted = self.books

        if books_sorted:
            [print(book.get_title()) for book in books_sorted]
        else:
            print("No books to print: Bookshelf is empty!  Find some books!")

    def print_books_info(self, sort_val=None):
        """Print the full book information for all books in the bookshelf (not including reviews), 
        sorted by the sort method (if provided)."""
        if sort_val:
            raise Exception("Need to make sort() work with the Books class")
        else:
            books_sorted = self.books

        if books_sorted:
            [print(book.get_book_info(), '\n') for book in books_sorted]
        else:
            print(
                "No books to print info: Bookshelf is empty!  Find some books!"
            )

    def print_reviews(self, sort_val=None):
        """Print the full review information for all books in the bookshelf, 
        sorted by the sort method (if provided)."""

        if sort_val:
            raise Exception("Need to make sort() work with the Books class")
        else:
            books_sorted = self.books

        if books_sorted:
            for book in books_sorted:
                book.print_reviews()
                print()
        else:
            print(
                "No books to print reviews for: Bookshelf is empty!  Find some books!"
            )

    def print_ascii_books(self,
                          sort_val=None,
                          letters_per_ascii_book=20,
                          books_per_row=14):
        '''method to print the bookshelf in ascii art format, sorted by the value provided. 
        The height of each shelf/book can be controlled by the letters_per_ascii_book, and 
        the width can be controlled by the books_per_row.
        
        Format inspired by https://codegolf.stackexchange.com/questions/111833/ascii-bookshelves'''
        if sort_val:
            raise Exception("Need to make sort() work with the Books class")
        else:
            books_sorted = self.books

        books = [book.get_title() for book in self.books]
        num_books = len(books)
        books_count = len(books)
        k = '|' + '-----' * books_per_row + '|'
        if books_count:
            while books_count:
                books_in_row = books_count % books_per_row or books_per_row
                print(k + '\n' +
                      ('|' + '     ' * (books_per_row - books_in_row) +
                       '/___/' * books_in_row + '|'))
                num_letters = letters_per_ascii_book
                while num_letters:
                    book_string = ''
                    col_string = ''
                    for i in range(0, books_in_row):
                        temp_book = books[num_books - books_count + i]
                        if letters_per_ascii_book - num_letters < len(
                                temp_book):
                            book_string_letter = temp_book[
                                letters_per_ascii_book - num_letters]
                        else:
                            book_string_letter = ' '
                        book_string += f'| {book_string_letter} |'
                        col_string += f' {num_books - books_count + i + 1:-2}  '
                    print('|' + '     ' * (books_per_row - books_in_row) +
                          book_string + '|')
                    num_letters -= 1
                print('|' + '     ' * (books_per_row - books_in_row) +
                      "^---^" * books_in_row + '|' + '\n' + k)
                print('|' + '     ' * (books_per_row - books_in_row) +
                      col_string + '|')
                books_count -= books_in_row
        else:
            print(k + '\n' + ('|' + '     ' * books_per_row + '|' + '\n') *
                  (letters_per_ascii_book + 2) + k)
            print("No books to print: Bookshelf is empty!  Find some books!")

# %% [markdown]
# ### <u>__Book__</u> (class):
#
# 1. Purpose
#     1. Record each book the user has on their list with descriptive information and references to any reviews made of the book.
#
# 1. Methods/functions
#     1. Managing books
#         1. Edit Book
#         1. __add_review__
#         1. __\_\_init\_\___
#         1. __\_\_repr\_\___
#     1. Ways to return/display my books
#         1. __get_title__ (Get Book name)
#         1. __get_book_info__ (Get all book info)
#         1. Return all books entered/reviewed
#         1. Return Review(s)
#             1. __print_reviews__
#         1. Return Actionable Items across all books
#
# 1. Expected i/o and attributes
#     1. Class attributes
#         1. __Book.book_count__ (how many books are there?)
#         1. Book statuses (Reviewed, Want to Read, Read_No_Review, Don't want to read)
#             1. __Book.book_statuses__
#         1. Formats (Physical Book, ebook, Audiobook, Other)
#             1. __Book.formats__
#     1. Instance attributes
#         1. __title__
#         1. __author__
#         1. __ISBN__
#         1. __url__ (to Amazon/goodreads/etc.)
#         1. __recommended_by__ (who recommended the book)
#         1. __format_consumed__ (Physical Book, ebook, Audiobook, Other)
#         1. __other__ (text field for whatever additional notes the user would like to record about the book,
#             not including review information)
#         1. __book_status__ (Reviewed, Want to Read, Read_No_Review, Don't want to read)
#         1. __reviews__ (list)

# %% [markdown]
# #### class Book()

# %%
import functools





@functools.total_ordering
class Book():
    '''An entity that represents a book and associated data.
    
    Class Attributes:
    book_count
    book_statuses = 1: 'Want to Read', 
                    2: 'Reviewed', 
                    3: 'Read_No_Review', 
                    4: 'Don't want to read'
    
    Instance Attributes:
'Title', 'Author', 'ISBN', 'Average Rating', 'Publisher', 'Binding', 'Year Published', 'Original Publication Year', 
'Date Read', 'Date Added', 'Bookshelves', 'My Review', 'My Rating', 

    title
    author
    ISBN
    url (to Amazon/goodreads/etc.)
    recommended_by (who recommended the book)
    other (text field for whatever additional notes the user would like to record about the book, 
        not including review information)
    book_status - (Want to Read, Reviewed, Read_No_Review, Don't want to read)
    bookshelves (list of bookshelves the book has been added to)
    reviews
    
    Methods:
    get_title
    get_book_info
    print_reviews
    add_review
    '''
    book_count = 0

    book_statuses = {
        1: "Want to Read",
        2: "Reviewed",
        3: "Read No Review",
        4: "Don't want to read"
    }

    def __init__(self,
                 title=None,
                 author=None,
                 ISBN=None,
                 url=None,
                 recommended_by=None,
                 other=None,
                 book_status=1,
                 bookshelves=[],
                 review=None):
        print(f'self.bookshelves = self.bookshelves\nbookshelves = {bookshelves}')

        if title == None:
            self.title = input("Enter a title: ")
            self.author = input("Enter the author: ")
            self.ISBN = input("Enter the ISBN (if you have one): ")
            self.url = input(
                "Enter a url for Amazon/Goodreads/etc.(if you have one): ")
            self.recommended_by = input(
                "Enter details for who recommended the book (if you have one): "
            )
            self.other = input(
                "Enter any additional notes the you would like to record about the book, \
                \not including review information: ")
            self.book_status = int(
                input('Enter any number for the status of the book: \n\
                1 = "Want to Read"\n\
                2 = "Read, want to review now"\n\
                3 = "Read, but don\'t want to review now"\n\
                4 = "Don\'t want to read"\n\
                Status: '))
            self.bookshelves = bookshelves
        else:
            self.title = title
            self.author = author
            self.ISBN = ISBN
            self.url = url
            self.recommended_by = recommended_by
            self.other = other
            self.book_status = Book.book_statuses[book_status]
            self.bookshelves = bookshelves

        if review == None:
            self.reviews = []
            if self.book_status == 2:
                if int(
                        input(
                            'Would you like to review this book now? (1 = Yes, 0 = No)\n'
                        )) == 1:
                    self.add_review()
                else:
                    self.book_status = Book.book_statuses[3]
                    print(f"Changing book status to: {self.book_status}")
        else:
            self.add_review(review)
        Book.book_count += 1

    def __lt__(self, other):
        try:
            return self.title < other.title
        except:
            return False

    def __eq__(self, other):
        try:
            return self.title == other.title
        except:
            return False

    def __repr__(self):
        return self.title

    def __str__(self):
        return self.title

    def get_title(self):
        return self.title

    def get_book_info(self):
        
        return (f"{self}\n\
        Author: {self.author}\n\
        ISBN: {self.ISBN}\n\
        url: {self.url}\n\
        Recommended by: {self.recommended_by}\n\
        Other: {self.other}\n\
        Status: {self.book_status}\n\
        Bookshelves: {', '.join(str(bookshelf) for bookshelf in self.bookshelves)}\n\
        Reviews: {len(self.reviews)}")

    def add_to_bookshelf(self, bookshelf=None):
        '''method to ad a book to a bookshelf and prompt user if no bookshelf provided. Possible states: 
            1. bookshelf provided
            2. No bookshelf provided - user prompted to pick a bookshelf or add a bookshelf'''
        if bookshelf == None:
            bookshelves = Bookshelf.bookshelves
            counter = 0
            words = f"Choose a bookshelf to add {self} to:\n\
            Enter 'a' to add a new bookshelf"

            for bookshelf in bookshelves:
                words += f"\n\tEnter '{counter}' to add to {bookshelf}"
                counter += 1
            words += f"\nBookshelf choice: "
            while True:
                chosen_bookshelf = input(words).lower()
                if chosen_bookshelf == 'a' or int(chosen_bookshelf) in range(
                        0, counter):
                    if chosen_bookshelf == 'a':
                        bookshelf = Bookshelf()
                    else:
                        bookshelf = bookshelves[int(chosen_bookshelf)]
                    break
                else:
                    print("\nPlease try again")

            bookshelf.add_book(self)
            print(f"{self} added to {bookshelf}")

    def add_review(self, review=None):
        if review == None:
            self.reviews.append(Review(self))
        else:
            self.reviews.append(review)
        self.book_status = Book.book_statuses[2]
        for bookshelf in self.bookshelves:
            bookshelf.reviews_count += 1

        print(f"\nReview added to {self.title}:\n\
        {self.reviews[-1]}")

    def print_reviews(self, sort_val=None):
        if sort_val:
            raise Exception("Need to make sort() work with the Books class")
        else:
            reviews_sorted = self.reviews

        if reviews_sorted:
            for review in reviews_sorted:
                print(review, '\n')
        else:
            print(f"{self.title}: No reviews yet!")

# %% [markdown]
# ### <u>__Review__</u> (class):
#
# 1. Purpose
#     1. Capture reader notes related to a book
#
# 1. Methods/functions
#     1. Managing reviews
#         1. Edit Review
#         1. __\_\_init\_\___
#         1. __\_\_repr\_\___
#     1. Ways to return/display my reviews
#         1. __get_title__ (Get Book name)
#         1. Return all reviews entered
#         1. Return Highlighted Sections across all books
#         1. Return Actionable Items across all books
#
# 1. Expected i/o and attributes
#     1. Class attributes
#         1. __Review.review_count__ (how many books are there?)
#         1. __Review.rating__ (1-5)
#     1. Instance attributes
#         1. __title__ (title of the book being reviewed)
#         1. __rating__ (1-5)
#         1. __start_date__
#         1. __end_date__
#         1. __big_idea__
#         1. __other_notes_takeaways__

# %% [markdown]
# #### class Review()

# %%
class Review():
    '''An entity that represents a book review and associated data.
    
    Class Attributes:
    rating (1-5)
    review_count
    formats = 1: "Physical Book",
              2: "ebook",
              3: "Audiobook",
              4: "Other"

    Instance Attributes:
    title (title of the book being reviewed)
    rating (1-5)
    start_date
    end_date
    big_idea
    other_notes_takeaways
    format_consumed
        
    Methods:
    get_title
    '''
    formats = {1: "Physical Book", 2: "ebook", 3: "Audiobook", 4: "Other"}

    review_count = 0
    rating = range(1, 5)

    def __init__(self,
                 book=None,
                 rating=None,
                 start_date=None,
                 end_date=None,
                 big_idea=None,
                 other_notes_takeaways=None,
                 format_consumed=4):
        if book == None:
            raise Exception("Need a book!")
        elif rating == None:
            self.title = book.title
            self.rating = self.verify_rating(rating)  #add/verify the rating
            self.start_date = input("Enter a start_date: ")
            self.end_date = input("Enter a end_date: ")
            self.big_idea = input("Enter the big_idea: ")
            self.other_notes_takeaways = input("Enter other_notes_takeaways: ")
            self.format_consumed = int(
                input('Enter any number for the format of the book: \n\
                1 = "Physical Book"\n\
                2 = "ebook"\n\
                3 = "Audiobook"\n\
                4 = "Other"\n\
                Format: '))
        else:
            self.title = book.title
            self.rating = self.verify_rating(rating)  #add/verify the rating
            self.start_date = start_date
            self.end_date = end_date
            self.big_idea = big_idea
            self.other_notes_takeaways = other_notes_takeaways
            self.format_consumed = Review.formats[format_consumed]
        book.add_review(self)
        Review.review_count += 1

    def verify_rating(self, rating=None):
        '''method to verify if rating is in 1-5.  Possible states: 
            1. no rating provided
            2. rating provided is not in range
            3. rating is ok'''
        if rating == None:
            rating = input("Enter a rating (1-5 as an integer): ")
        while rating not in range(1, 6) or type(rating) is not int:
            print(rating)
            try:
                rating = int(rating)
                if rating not in range(1, 6):
                    raise
            except:
                rating = input(
                    "Invalid entry - please enter a rating (1-5 as an integer): "
                )
        return rating

    def get_title(self):
        return self.title

    def __repr__(self):
        return (f"{self.title}\n\
        rating: {self.rating}\n\
        start_date: {self.start_date}\n\
        end_date: {self.end_date}\n\
        Big Idea: {self.big_idea}\n\
        Other notes & takeaways: {self.other_notes_takeaways}\n\
        format_consumed: {self.format_consumed}")
    
    def __str__(self):
        return (f"{self.title}\n\
        rating: {self.rating}\n\
        start_date: {self.start_date}\n\
        end_date: {self.end_date}\n\
        Big Idea: {self.big_idea}\n\
        Other notes & takeaways: {self.other_notes_takeaways}\n\
        format_consumed: {self.format_consumed}")

# %% [markdown]
# ### <u>__Bookshelf_manager__</u> (class):
#
# 1. Purpose
#     1. The user interface/interaction manager for bookshelves, books, and reviews.
#
#
# 1. Methods/functions
#
# 1. Expected i/o and attributes

# %% [markdown]
# #### class Bookshelf_manager()

# %%
import time
import os


class Bookshelf_manager:
    """This class creates new/loads instances of the bookshelf, book, and review objects 
    and allows for user interaction"""

    menu = {
        'L': '(L)ist my books',
        'G': '(G)et the info about a book',
        'A': '(A)dd a book',
        'R': '(R)eview a book',
        'C': 'save and (C)lose',
        'S': '(S)ettings'
    }

    def __init__(self):
        #Generate new interaction instance and allow users to interact with their bookshelves until the user selects save and close = "C"
        self.intro()  # introduce the program
        self.load_or_add_bookshelf()  # load or add a bookshelf

        while True:

            #Prompt to save and close
            menu = Bookshelf_manager.menu
            menu_option = ""
            while True:
                print(f'testing: {self.bookshelf}')
                print('\nWhat would you like to do next?\n\nEnter: ')
                for item in menu:
                    print(f'\t({item}) to {menu[item]}')
                menu_option = input('\n').upper()
                if menu_option in menu:
                    break
                else:
                    os.system('clear')
                    print(f"Your entry '{menu_option}' is not recognized")
            if menu_option == "L":
                self.list_books()
            elif menu_option == "G":
                self.get_book_info()
            elif menu_option == "A":
                self.bookshelf.add_book()
            elif menu_option == "C":
                self.bookshelf.save_bookshelf()
                print(f'{self.bookshelf} saved.  Have a wonderful day!\n')
                break

     

    def intro(self):
        print()
        print(
            "Let's manage our bookshelf. You will be prompted to load an existing bookshelf or set up a new one."
        )
        print("Then you will have the opportunity to add books and reviews.")
        print(
            "You can see the books on your bookshelf, and select them to see their details."
        )
        print("First let's set up your bookshelf.")
        time.sleep(0)
        print()

    def load_or_add_bookshelf(self):
        load_or_add = ""
        while True:
            load_or_add = input(
                'Would you like to load an existing bookshelf, or add a new one? Enter (L) to load an existing bookshelf or (A) to add a new bookshelf\n'
            ).upper()
            if load_or_add == "L" or load_or_add == "A":
                break
        if load_or_add == "A":
            os.system('clear')
            bookshelf_name = input(
                "What would you like to call your new bookshelf?\n")
            self.bookshelf = Bookshelf(bookshelf_name)
            print(f'\n{self.bookshelf} created!\n')
        else:
            os.system('clear')
            while True:
              try:
                  bookshelf_file = input(
                      "What is the file name (with path) of the bookshelf you would like to load?\n"
                  )
                  self.bookshelf = Bookshelf.load_bookshelf(bookshelf_file)
                  break
              except:
                  print(f"Your entry '{bookshelf_file}' is not recognized")
            self.bookshelf.reset_bookshelf()
            print(f'\n"{self.bookshelf}" bookshelf loaded:')
            self.bookshelf.print_bookshelf_summary()
            print()

    def list_books(self):
        os.system('clear')
        self.bookshelf.print_ascii_books()
    
    def get_book_info(self):
        os.system('clear')
        self.bookshelf.print_ascii_books()
        prompt = int(input("Which book would you like? (Enter the number below the book on the bookshelf)\n"))
        print('\n' + self.bookshelf.books[prompt - 1].get_book_info() +
              '\n\nReview: ')
        self.bookshelf.books[prompt - 1].print_reviews()

# %%
menu = {
        'B':'add a (B)ook',
        'R':'(R)eview a book',
        'C':'save and (C)lose',
        'S':'(S)ettings'
    }

menu['B']
'z' in menu
# Out:
# False

# %% [markdown]
# ### <u>__Highlighted Sections__</u> (class):
#
# 1. Purpose
#     1. Capture Quotes or other highlighted sections)
#
# 1. Methods/functions
#     1.  Set Highlight
#     1.  Get Highlight
#
# 1. Expected i/o and attributes
#     1. page #
#     1. Details
#
# ### <u>__Actionable Items__</u> (class):
#
# 1. Purpose
#     1. (Ideas I might want to try in the future and notes regarding the idea.)
#
# 1. Methods/functions
#     1.
#
# 1. Expected i/o and attributes
#     1. Actionable Item description/information/name,
#     1. due date?
#
# ### <u>__Format consumed__</u> (possible class with children):
#
# 1. (Physical Book, ebook, Audiobook, Other, etc.)

# %% [markdown]
# # Example:
#
# 1. Create an example bookshelf
# 1. Create a couple books
# 1. Add the books to my bookshelf (using different methods)
# 1. Create a couple reviews
# 1. Print out the example bookshelf
# 1. Save the bookshelf

# %% [markdown]
# ## Create an example bookshelf

# %%
# 1. Create an example bookshelf
my_bookshelf = Bookshelf("demo")

# %%
print(my_bookshelf)
print(my_bookshelf.books)
print(my_bookshelf.get_books())
my_bookshelf.print_books_titles()
my_bookshelf.print_books_info()
my_bookshelf.print_reviews()
# print(a.book_statuses[2])
# Out:
# demo
# []
# []
# No books to print: Bookshelf is empty!  Find some books!
# No books to print info: Bookshelf is empty!  Find some books!
# No books to print reviews for: Bookshelf is empty!  Find some books!

# %% [markdown]
# ## Create a couple books
#
# ### Create "Book1: Hello World!"

# %%
# 1. Create a couple books

book1 = Book("Book1: Hello World!", book_status=2)
print(book1.__dict__)
print()

print(f"Book: {book1}")
print(f"Book Title: {book1.title}")
print(f"\"{book1.title}\" Author: {book1.author}")
print(f"\"{book1.title}\" ISBN: {book1.ISBN}")
print(f"\"{book1.title}\" url: {book1.url}")
print(f"\"{book1.title}\" Recommended by: {book1.recommended_by}")
print(f"\"{book1.title}\" Other: {book1.other}")
print(f"\"{book1.title}\" Status: {book1.book_status}")
print()
print()
# Out:
# self.bookshelves = self.bookshelves
# bookshelves = []
# {'title': 'Book1: Hello World!', 'author': None, 'ISBN': None, 'url': None, 'recommended_by': None, 'other': None, 'book_status': 'Reviewed', 'bookshelves': [], 'reviews': []}
#
# Book: Book1: Hello World!
# Book Title: Book1: Hello World!
# "Book1: Hello World!" Author: None
# "Book1: Hello World!" ISBN: None
# "Book1: Hello World!" url: None
# "Book1: Hello World!" Recommended by: None
# "Book1: Hello World!" Other: None
# "Book1: Hello World!" Status: Reviewed

# %% [markdown]
# ### Create "Book2: Thinking Fast & Slow"

# %%
book2 = Book("Book2: Thinking Fast & Slow", "Daniel Kahnamen")
print(book2.__dict__)
print()
print(book2)
print()
book2.get_title()
print()
print(book2.get_book_info())
# Out:
# self.bookshelves = self.bookshelves
# bookshelves = []
# {'title': 'Book2: Thinking Fast & Slow', 'author': 'Daniel Kahnamen', 'ISBN': None, 'url': None, 'recommended_by': None, 'other': None, 'book_status': 'Want to Read', 'bookshelves': [], 'reviews': []}
#
# Book2: Thinking Fast & Slow
#
#
# Book2: Thinking Fast & Slow
#         Author: Daniel Kahnamen
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Want to Read
#         Bookshelves:
#         Reviews: 0

# %%
print(my_bookshelf)
print(my_bookshelf.books)
print(my_bookshelf.get_books())
my_bookshelf.print_books_titles()
my_bookshelf.print_books_info()
my_bookshelf.print_reviews()
# print(a.book_statuses[2])
# Out:
# demo
# []
# []
# No books to print: Bookshelf is empty!  Find some books!
# No books to print info: Bookshelf is empty!  Find some books!
# No books to print reviews for: Bookshelf is empty!  Find some books!

# %% [markdown]
# ## Add the books to my bookshelf (using different methods)

# %%
# 1. Add the books to my bookshelf (using different methods)
my_bookshelf.books.append(book1)
my_bookshelf.add_book(book2)
# Out:
# testing: Book2: Thinking Fast & Slow
# Book2: Thinking Fast & Slow
#         Author: Daniel Kahnamen
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Want to Read
#         Bookshelves: demo
#         Reviews: 0
# added to demo

# %%
my_bookshelf.print_books_titles()
print("\n\n")
#my_bookshelf.print_books_titles("sort")
# Out:
# Book1: Hello World!
# Book2: Thinking Fast & Slow

# %%
print(my_bookshelf)
print(my_bookshelf.books)
print(my_bookshelf.get_books())
my_bookshelf.print_books_titles()
my_bookshelf.print_books_info()
my_bookshelf.print_reviews()
# print(a.book_statuses[2])
# Out:
# demo
# [Book1: Hello World!, Book2: Thinking Fast & Slow]
# [Book1: Hello World!, Book2: Thinking Fast & Slow]
# Book1: Hello World!
# Book2: Thinking Fast & Slow
# Book1: Hello World!
#         Author: None
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Reviewed
#         Bookshelves: demo
#         Reviews: 0
#
# Book2: Thinking Fast & Slow
#         Author: Daniel Kahnamen
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Want to Read
#         Bookshelves: demo
#         Reviews: 0
#
# Book1: Hello World!: No reviews yet!
#
# Book2: Thinking Fast & Slow: No reviews yet!

# %% [markdown]
# ## Create a couple reviews

# %%
# 1. Create a couple reviews

#Create review for book 1
review1 = Review(book1, rating=5)
#book1.add_review(review1)
# print(review1)

print()

#Create review for book 2
review2 = Review(
    book2,
    rating=1,
    start_date="2019-01-01",
    end_date="2019-02-29",
    big_idea="The world needs a Hello",
    other_notes_takeaways=
    "\n\t\t- Bullet 1\n\t\t- Bullet 2\n\t\t- ...\n\t\t- Bullet n")
#book2.add_review(review2)

# print(review2)
# Out:
# Review added to Book1: Hello World!:
#         Book1: Hello World!
#         rating: 5
#         start_date: None
#         end_date: None
#         Big Idea: None
#         Other notes & takeaways: None
#         format_consumed: Other
#
#
# Review added to Book2: Thinking Fast & Slow:
#         Book2: Thinking Fast & Slow
#         rating: 1
#         start_date: 2019-01-01
#         end_date: 2019-02-29
#         Big Idea: The world needs a Hello
#         Other notes & takeaways:
# 		- Bullet 1
# 		- Bullet 2
# 		- ...
# 		- Bullet n
#         format_consumed: Other

# %%
print(my_bookshelf)
print(my_bookshelf.books)
print(my_bookshelf.get_books())
my_bookshelf.print_books_titles()
my_bookshelf.print_books_info()
my_bookshelf.print_reviews()
# print(a.book_statuses[2])
# Out:
# demo
# [Book1: Hello World!, Book2: Thinking Fast & Slow]
# [Book1: Hello World!, Book2: Thinking Fast & Slow]
# Book1: Hello World!
# Book2: Thinking Fast & Slow
# Book1: Hello World!
#         Author: None
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Reviewed
#         Bookshelves: demo
#         Reviews: 1
#
# Book2: Thinking Fast & Slow
#         Author: Daniel Kahnamen
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Reviewed
#         Bookshelves: demo
#         Reviews: 1
#
# Book1: Hello World!
#         rating: 5
#         start_date: None
#         end_date: None
#         Big Idea: None
#         Other notes & takeaways: None
#         format_consumed: Other
#
#
# Book2: Thinking Fast & Slow
#         rating: 1
#         start_date: 2019-01-01
#         end_date: 2019-02-29
#         Big Idea: The world needs a Hello
#         Other notes & takeaways:
# 		- Bullet 1
# 		- Bullet 2
# 		- ...
# 		- Bullet n
#         format_consumed: Other

# %% [markdown]
# ## Print out the example bookshelf

# %%
print("print(my_bookshelf)")
print(my_bookshelf)

print("\n---\n\n print(my_bookshelf.books)")
print(my_bookshelf.books)

print("\n---\n\n my_bookshelf.print_books_titles()")
my_bookshelf.print_books_titles()

print("\n---\n\n my_bookshelf.print_ascii_books()")
my_bookshelf.print_ascii_books()

print("\n---\n\n my_bookshelf.print_books_info()")
my_bookshelf.print_books_info()

print("\n---\n\n print(my_bookshelf.get_books())")
print(my_bookshelf.get_books())

print("\n---\n\n print(my_bookshelf.print_reviews())")
my_bookshelf.print_reviews()

print(
    "\n---\n\n [print(book.get_title(),'\\n') for book in my_bookshelf.books]")
[print(book.get_title(), '\n') for book in my_bookshelf.books]

print(
    "\n---\n\n [print(book.get_book_info(),'\\n') for book in my_bookshelf.books]"
)
[print(book.get_book_info(), '\n') for book in my_bookshelf.books]

print(
    "\n---\n\n [print(review,'\\n') for book in my_bookshelf.books for review in book.reviews ]"
)
[print(review, '\n') for book in my_bookshelf.books for review in book.reviews]
# Out:
# print(my_bookshelf)
# demo
#
# ---
#
#  print(my_bookshelf.books)
# [Book1: Hello World!, Book2: Thinking Fast & Slow]
#
# ---
#
#  my_bookshelf.print_books_titles()
# Book1: Hello World!
# Book2: Thinking Fast & Slow
#
# ---
#
#  my_bookshelf.print_ascii_books()
# |----------------------------------------------------------------------|
# |                                                            /___//___/|
# |                                                            | B || B ||
# |                                                            | o || o ||
# |                                                            | o || o ||
# |                                                            | k || k ||
# |                                                            | 1 || 2 ||
# |                                                            | : || : ||
# |                                                            |   ||   ||
# |                                                            | H || T ||
# |                                                            | e || h ||
# |                                                            | l || i ||
# |                                                            | l || n ||
# |                                                            | o || k ||
# |                                                            |   || i ||
# |                                                            | W || n ||
# |                                                            | o || g ||
# |                                                            | r ||   ||
# |                                                            | l || F ||
# |                                                            | d || a ||
# |                                                            | ! || s ||
# |                                                            |   || t ||
# |                                                            ^---^^---^|
# |----------------------------------------------------------------------|
# |                                                              1    2  |
#
# ---
#
#  my_bookshelf.print_books_info()
# Book1: Hello World!
#         Author: None
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Reviewed
#         Bookshelves: demo
#         Reviews: 1
#
# Book2: Thinking Fast & Slow
#         Author: Daniel Kahnamen
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Reviewed
#         Bookshelves: demo
#         Reviews: 1
#
#
# ---
#
#  print(my_bookshelf.get_books())
# [Book1: Hello World!, Book2: Thinking Fast & Slow]
#
# ---
#
#  print(my_bookshelf.print_reviews())
# Book1: Hello World!
#         rating: 5
#         start_date: None
#         end_date: None
#         Big Idea: None
#         Other notes & takeaways: None
#         format_consumed: Other
#
#
# Book2: Thinking Fast & Slow
#         rating: 1
#         start_date: 2019-01-01
#         end_date: 2019-02-29
#         Big Idea: The world needs a Hello
#         Other notes & takeaways:
# 		- Bullet 1
# 		- Bullet 2
# 		- ...
# 		- Bullet n
#         format_consumed: Other
#
#
#
# ---
#
#  [print(book.get_title(),'\n') for book in my_bookshelf.books]
# Book1: Hello World!
#
# Book2: Thinking Fast & Slow
#
#
# ---
#
#  [print(book.get_book_info(),'\n') for book in my_bookshelf.books]
# Book1: Hello World!
#         Author: None
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Reviewed
#         Bookshelves: demo
#         Reviews: 1
#
# Book2: Thinking Fast & Slow
#         Author: Daniel Kahnamen
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Reviewed
#         Bookshelves: demo
#         Reviews: 1
#
#
# ---
#
#  [print(review,'\n') for book in my_bookshelf.books for review in book.reviews ]
# Book1: Hello World!
#         rating: 5
#         start_date: None
#         end_date: None
#         Big Idea: None
#         Other notes & takeaways: None
#         format_consumed: Other
#
# Book2: Thinking Fast & Slow
#         rating: 1
#         start_date: 2019-01-01
#         end_date: 2019-02-29
#         Big Idea: The world needs a Hello
#         Other notes & takeaways:
# 		- Bullet 1
# 		- Bullet 2
# 		- ...
# 		- Bullet n
#         format_consumed: Other
# [None, None]

# %%
print(f'Bookshelf.bookshelf_count: {Bookshelf.bookshelf_count}')
print(f'Book.book_count: {Book.book_count}')
print(f'Review.review_count: {Review.review_count}')
print()
print(f'my_bookshelf.name: {my_bookshelf.name}')
print(f'my_bookshelf.books_count: {my_bookshelf.books_count}')
print(f'my_bookshelf.reviews_count: {my_bookshelf.reviews_count}')
print(f'my_bookshelf.books: {my_bookshelf.books}')
# Out:
# Bookshelf.bookshelf_count: 1
# Book.book_count: 2
# Review.review_count: 2
#
# my_bookshelf.name: demo
# my_bookshelf.books_count: 1
# my_bookshelf.reviews_count: 2
# my_bookshelf.books: [Book1: Hello World!, Book2: Thinking Fast & Slow]

# %% [markdown]
# ## Save the bookshelf

# %%
my_bookshelf.save_bookshelf()

# %% [markdown]
# ## Review the bookshelf, book, and review instances

# %%
print(my_bookshelf.__dict__)

for book in my_bookshelf.books:
    print(book.__dict__, '\n')

    for review in book.reviews:
        print(review.__dict__)

    print()
# Out:
# {'name': 'demo', 'books': [Book1: Hello World!, Book2: Thinking Fast & Slow], 'books_count': 1, 'reviews_count': 2}
# {'title': 'Book1: Hello World!', 'author': None, 'ISBN': None, 'url': None, 'recommended_by': None, 'other': None, 'book_status': 'Reviewed', 'bookshelves': [demo], 'reviews': [Book1: Hello World!
#         rating: 5
#         start_date: None
#         end_date: None
#         Big Idea: None
#         Other notes & takeaways: None
#         format_consumed: Other]}
#
# {'title': 'Book1: Hello World!', 'rating': 5, 'start_date': None, 'end_date': None, 'big_idea': None, 'other_notes_takeaways': None, 'format_consumed': 'Other'}
#
# {'title': 'Book2: Thinking Fast & Slow', 'author': 'Daniel Kahnamen', 'ISBN': None, 'url': None, 'recommended_by': None, 'other': None, 'book_status': 'Reviewed', 'bookshelves': [demo], 'reviews': [Book2: Thinking Fast & Slow
#         rating: 1
#         start_date: 2019-01-01
#         end_date: 2019-02-29
#         Big Idea: The world needs a Hello
#         Other notes & takeaways:
# 		- Bullet 1
# 		- Bullet 2
# 		- ...
# 		- Bullet n
#         format_consumed: Other]}
#
# {'title': 'Book2: Thinking Fast & Slow', 'rating': 1, 'start_date': '2019-01-01', 'end_date': '2019-02-29', 'big_idea': 'The world needs a Hello', 'other_notes_takeaways': '\n\t\t- Bullet 1\n\t\t- Bullet 2\n\t\t- ...\n\t\t- Bullet n', 'format_consumed': 'Other'}

# %% [markdown]
# # Main Bookshelf Program

# %%
# Main Bookshelf Program - Conor Healy
# The main program prompts the user to load a bookshelf or create a new one.

import time

Bookshelf_manager()
# Out:
# Let's manage our bookshelf. You will be prompted to load an existing bookshelf or set up a new one.
# Then you will have the opportunity to add books and reviews.
# You can see the books on your bookshelf, and select them to see their details.
# First let's set up your bookshelf.
#
# Would you like to load an existing bookshelf, or add a new one? Enter (L) to load an existing bookshelf or (A) to add a new bookshelf
# l
# What is the file name (with path) of the bookshelf you would like to load?
# demo.bkshlf
#
# "demo" bookshelf loaded:
# Books: 2
# Reviews: 2
#
# testing: demo
#
# What would you like to do next?
#
# Enter:
# 	(L) to (L)ist my books
# 	(G) to (G)et the info about a book
# 	(A) to (A)dd a book
# 	(R) to (R)eview a book
# 	(C) to save and (C)lose
# 	(S) to (S)ettings
#
# l
# |----------------------------------------------------------------------|
# |                                                            /___//___/|
# |                                                            | B || B ||
# |                                                            | o || o ||
# |                                                            | o || o ||
# |                                                            | k || k ||
# |                                                            | 1 || 2 ||
# |                                                            | : || : ||
# |                                                            |   ||   ||
# |                                                            | H || T ||
# |                                                            | e || h ||
# |                                                            | l || i ||
# |                                                            | l || n ||
# |                                                            | o || k ||
# |                                                            |   || i ||
# |                                                            | W || n ||
# |                                                            | o || g ||
# |                                                            | r ||   ||
# |                                                            | l || F ||
# |                                                            | d || a ||
# |                                                            | ! || s ||
# |                                                            |   || t ||
# |                                                            ^---^^---^|
# |----------------------------------------------------------------------|
# |                                                              1    2  |
# testing: demo
#
# What would you like to do next?
#
# Enter:
# 	(L) to (L)ist my books
# 	(G) to (G)et the info about a book
# 	(A) to (A)dd a book
# 	(R) to (R)eview a book
# 	(C) to save and (C)lose
# 	(S) to (S)ettings
#
# g
# |----------------------------------------------------------------------|
# |                                                            /___//___/|
# |                                                            | B || B ||
# |                                                            | o || o ||
# |                                                            | o || o ||
# |                                                            | k || k ||
# |                                                            | 1 || 2 ||
# |                                                            | : || : ||
# |                                                            |   ||   ||
# |                                                            | H || T ||
# |                                                            | e || h ||
# |                                                            | l || i ||
# |                                                            | l || n ||
# |                                                            | o || k ||
# |                                                            |   || i ||
# |                                                            | W || n ||
# |                                                            | o || g ||
# |                                                            | r ||   ||
# |                                                            | l || F ||
# |                                                            | d || a ||
# |                                                            | ! || s ||
# |                                                            |   || t ||
# |                                                            ^---^^---^|
# |----------------------------------------------------------------------|
# |                                                              1    2  |
# Which book would you like? (Enter the number below the book on the bookshelf)
# 2
#
# Book2: Thinking Fast & Slow
#         Author: Daniel Kahnamen
#         ISBN: None
#         url: None
#         Recommended by: None
#         Other: None
#         Status: Reviewed
#         Bookshelves: demo
#         Reviews: 1
#
# Review:
# Book2: Thinking Fast & Slow
#         rating: 1
#         start_date: 2019-01-01
#         end_date: 2019-02-29
#         Big Idea: The world needs a Hello
#         Other notes & takeaways:
# 		- Bullet 1
# 		- Bullet 2
# 		- ...
# 		- Bullet n
#         format_consumed: Other
#
# testing: demo
#
# What would you like to do next?
#
# Enter:
# 	(L) to (L)ist my books
# 	(G) to (G)et the info about a book
# 	(A) to (A)dd a book
# 	(R) to (R)eview a book
# 	(C) to save and (C)lose
# 	(S) to (S)ettings
#
# a
# self.bookshelves = self.bookshelves
# bookshelves = [demo]
# Enter a title: asdf
# Enter the author: asdf
# Enter the ISBN (if you have one): asdf
# Enter a url for Amazon/Goodreads/etc.(if you have one): fdsa
# Enter details for who recommended the book (if you have one): asdf
# Enter any additional notes the you would like to record about the book,
# ot including review information: fdsa
# Enter any number for the status of the book:
#                 1 = "Want to Read"
#                 2 = "Read, want to review now"
#                 3 = "Read, but don't want to review now"
#                 4 = "Don't want to read"
#                 Status: 1
# testing: asdf
# asdf
#         Author: asdf
#         ISBN: asdf
#         url: fdsa
#         Recommended by: asdf
#         Other: fdsa
#         Status: 1
#         Bookshelves: demo, demo
#         Reviews: 0
# added to demo
# testing: demo
#
# What would you like to do next?
#
# Enter:
# 	(L) to (L)ist my books
# 	(G) to (G)et the info about a book
# 	(A) to (A)dd a book
# 	(R) to (R)eview a book
# 	(C) to save and (C)lose
# 	(S) to (S)ettings
#
# c
# demo saved.  Have a wonderful day!

# %%
# Main Bookshelf Program - Conor Healy
# The main program prompts the user to load a bookshelf or create a new one.

# Prompt user to add a bookshelf
new_bookshelf_name = input("What would you like to call your new bookshelf?\n")
new_bookshelf = Bookshelf(new_bookshelf_name)

print(new_bookshelf)
new_bookshelf.print_books_titles()
new_bookshelf.print_books_info()
new_bookshelf.print_reviews()

# %% [markdown]
# # Playground

# %%
# Prompt user to add a bookshelf
new_bookshelf_name = input("What would you like to call your new bookshelf?")
new_bookshelf = Bookshelf(new_bookshelf_name)

print(my_bookshelf)
my_bookshelf.print_books_titles()
my_bookshelf.print_books_info()
my_bookshelf.print_reviews()

# %% [markdown]
# ## Play with adding to bookshelves

# %%
Bookshelf.bookshelves[0].books
Bookshelf.get_bookshelves()

# %%
print(my_bookshelf.books)
print(my_bookshelf.books.sort(reverse = True))
print(my_bookshelf.books)
print(my_bookshelf.books.sort(reverse = False))
print(my_bookshelf.books)
print(sorted(my_bookshelf.books))
print(sorted(my_bookshelf.books, reverse = True))
print(my_bookshelf.books)

# %%
my_bookshelf.books.sort(reverse = True)
my_bookshelf.print_ascii_books()
prompt = int(input("which book would you like? \n"))
print('\n' + my_bookshelf.books[prompt-1].get_book_info() + '\n\nReview: ')
print(my_bookshelf.books[prompt-1].print_reviews())

# %%
type(book1.bookshelves[0])
# ', '.join(book1.bookshelves)

# %%
my_bookshelf.reset_bookshelf()

# %% [markdown]
# # ?my_bookshelf.books.sort()
